# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Real-estate.csv')

# %%
data.head()
# Out:
#    No  X1 date de transaction  X2 age de la maison  \
# 0   1                2012.917                 32.0
# 1   2                2012.917                 19.5
# 2   3                2013.583                 13.3
# 3   4                2013.500                 13.3
# 4   5                2012.833                  5.0
#
#    X3 distance jusqu'a la gare la plus proche  \
# 0                                    84.87882
# 1                                   306.59470
# 2                                   561.98450
# 3                                   561.98450
# 4                                   390.56840
#
#    X4 nombre de supermarket de proximite  X5 latitude  X6 longitude  \
# 0                                     10     24.98298     121.54024
# 1                                      9     24.98034     121.53951
# 2                                      5     24.98746     121.54391
# 3                                      5     24.98746     121.54391
# ...

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# No                                            0
# X1 date de transaction                        0
# X2 age de la maison                           0
# X3 distance jusqu'a la gare la plus proche    0
# X4 nombre de supermarket de proximite         0
# X5 latitude                                   0
# X6 longitude                                  0
# Y prix de la maison par unite de surface      0
# dtype: int64

# %% [markdown]
# # Division de donnée

# %%
X = data.iloc[:200 , :-1]
y = data.iloc[:200 , -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 30)

# %%
# Affichage des dimensions
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
# Out:
# X_train: (160, 7)
# y_train: (160,)

# %%
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# X_test: (40, 7)
# y_test: (40,)

# %% [markdown]
# #  Régression linéaire

# %%
modele_Lineaire = LinearRegression()

# %%
modele_Lineaire.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#       No  X1 date de transaction  X2 age de la maison  \
# 143  144                2013.500                 13.6
# 81    82                2013.000                 30.8
# 26    27                2012.667                  3.1
# 150  151                2013.250                 35.8
# 124  125                2012.917                  9.9
# 24    25                2013.000                 39.6
# 126  127                2013.083                 38.6
# 142  143                2013.417                 19.8
# 129  130                2013.417                 38.5
# 171  172                2013.083                  3.6
# 72    73                2013.583                 32.5
# 97    98                2013.083                 28.4
# 21    22                2013.417                 10.5
# 67    68                2013.500                  8.5
# 106  107                2013.083                 17.2
# 184  185                2012.750                 14.1
# ...

# %%
Prediction = modele_Lineaire.predict(X_test)
Prediction
# Out:
# array([44.18370457, 37.65563996, 47.15450538, 39.79152464, 47.60888107,
#        34.17385106, 34.5917991 , 42.0019817 , 42.31903992, 49.04659189,
#        44.09218252, 37.46319872, 49.65322217, 47.74527724, 47.89975676,
#        23.2264056 , 44.01823238, 48.48615627, 24.29040051, 17.62969896,
#        33.18958826, 45.79389339, 47.69075759, 41.80316532, 53.81358592,
#        46.42570374, 15.52113379, 40.5226825 , 44.66111625, 45.45509426,
#        40.53655074, 47.08904559, 31.63145666, 42.8630184 , 45.63866173,
#        32.06859588, 47.57467605, 39.67951645, 48.81507043, 44.16544723])

# %%
r2_score(y_test,Prediction)
# Out:
# 0.5888494052990836

# %%
print("Mean Squared Error:", mean_absolute_error(y_test, Prediction))
print("R2 Squared :", r2_score(y_test, Prediction))
# Out:
# Mean Squared Error: 5.9861803836985015
# R2 Squared : 0.5888494052990836

# %%
modele_Lineaire.score(X_test, y_test)
# Out:
# 0.5888494052990836

# %%
plt.scatter(y_test, Prediction)
plt.plot(X_test, modele_Lineaire.predict(X_test),color='blue', label="Scores predict")
plt.xlabel("Valeurs réelles")
plt.ylabel("Prédictions")
plt.title("Regression Lineaire sur le donnee d'entrainement")
plt.xlabel("REAL")
plt.ylabel("Score")
plt.legend()
plt.show()

# %%
plt.scatter(X_test, y_test, color='red', label="Donnees d'entrainement") 
plt.scatter(X_train, y_train, color='yellow', label="Donnees de test") 
plt.plot(X_test, modele_Lineaire.predict(X_test),color='blue', label="Scores predict")
plt.xlabel("Heure Etude")
plt.ylabel("Score")
plt.title("Regression Lineaire sur le donnee d'entrainement")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[389], line 1
# ----> 1 plt.scatter(X_test, y_test, color='red', label="Donnees d'entrainement")
#       2 plt.scatter(X_train, y_train, color='yellow', label="Donnees de test")
#       3 plt.plot(X_test, modele_Lineaire.predict(X_test),color='blue', label="Scores predict")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
# ...
